# %%
import sympy as sp

# %%
m1, m2, m3, M = sp.symbols('m1 m2 m3 M')
t = sp.symbols('t')
theta_m2 = sp.Function('theta_m2')(t)
theta_m3 = sp.Function('theta_m3')(t)
y_m2 = sp.Function('y_m2')(t)
y_M = sp.Function('y_M')(t)
theta_M = sp.symbols('theta_M')
l1, l2, l3 = sp.symbols('l1 l2 l3')
r = sp.symbols('r')
k1, k2, k3, k4, k5 = sp.symbols('k1 k2 k3 k4 k5')
c4, c5 = sp.symbols('c4 c5')
g = sp.symbols('g')

# %%
x_m2 = (y_M - y_m2) * sp.tan(theta_M)
delta_l2 = (y_M - y_m2) / sp.tan(theta_M)
l3_new = sp.sqrt((l3 * sp.sin(theta_m3) - x_m2)**2 + (l3 * sp.cos(theta_m3) - (y_m2 - l1 * theta_m2 + y_M))**2)
delta_l3 = l3_new - l3

# %%
ans = 0.5 * (m1 + m3) * (l1 * sp.diff(theta_m2, t))**2 + 0.5 * m2 * (sp.diff(y_m2, t))**2 + 0.5 * (m1 + m2 + m3) * (sp.diff(((y_M - y_m2) * sp.tan(theta_M)), t))**2 + 0.5 * M * (sp.diff(y_M, t))**2
T = ans.simplify()
sp.pprint(T)
# Out:
#                   2                                 2                      2   ↪
#       ⎛d         ⎞          2           ⎛d         ⎞           ⎛d         ⎞    ↪
# 0.5⋅M⋅⎜──(y_M(t))⎟  + 0.5⋅l₁ ⋅(m₁ + m₃)⋅⎜──(θₘ₂(t))⎟  + 0.5⋅m₂⋅⎜──(yₘ₂(t))⎟  + ↪
#       ⎝dt        ⎠                      ⎝dt        ⎠           ⎝dt        ⎠    ↪
#
# ↪                               2
# ↪      ⎛d            d         ⎞                    2
# ↪  0.5⋅⎜──(y_M(t)) - ──(yₘ₂(t))⎟ ⋅(m₁ + m₂ + m₃)⋅tan (θ_M)
# ↪      ⎝dt           dt        ⎠

# %%
ans = 0.5 * c4 * (sp.diff(delta_l3, t))**2 + 0.5 * c5 * (sp.diff(delta_l2, t))**2
D = ans.simplify()
sp.pprint(D)
# Out:
#     ⎛                                                                          ↪
#     ⎜   ⎛                                               ⎛               d      ↪
# 0.5⋅⎜c₄⋅⎜(l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))⋅⎜l₃⋅cos(θₘ₃(t))⋅──(θₘ₃ ↪
#     ⎝   ⎝                                               ⎝               dt     ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪                                                                              ↪
# ↪        ⎛  d            d         ⎞         ⎞                                 ↪
# ↪ (t)) + ⎜- ──(y_M(t)) + ──(yₘ₂(t))⎟⋅tan(θ_M)⎟ - (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - ↪
# ↪        ⎝  dt           dt        ⎠         ⎠                                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                              ⎛               ↪
# ↪                                                              ⎝(l₃⋅sin(θₘ₃(t) ↪
#
# ↪                                                                              ↪
# ↪                   ⎛     d                           d            d           ↪
# ↪  y_M(t) - yₘ₂(t))⋅⎜- l₁⋅──(θₘ₂(t)) + l₃⋅sin(θₘ₃(t))⋅──(θₘ₃(t)) + ──(y_M(t))  ↪
# ↪                   ⎝     dt                          dt           dt          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                 2                                            ↪
# ↪ ) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - y ↪
#
# ↪               2                                                              ↪
# ↪   d         ⎞⎞     2           ⎛                                             ↪
# ↪ + ──(yₘ₂(t))⎟⎟ ⋅tan (θ_M) + c₅⋅⎝(l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M ↪
# ↪   dt        ⎠⎠                                                               ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪       2⎞    2                                                                ↪
# ↪ ₘ₂(t)) ⎠⋅tan (θ_M)                                                           ↪
#
# ↪                                                                              ↪
# ↪   2                                                 2⎞ ⎛d            d       ↪
# ↪ ))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t)) ⎠⋅⎜──(y_M(t)) - ──(yₘ₂( ↪
# ↪                                                        ⎝dt           dt      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪     2⎞
# ↪    ⎞ ⎟
# ↪ t))⎟ ⎟
# ↪    ⎠ ⎠
# ↪ ──────
# ↪
# ↪

# %%
ans = 0.5 * k1 * (y_m2 + l1 * sp.sin(theta_m2))**2 + \
      0.5 * k2 * (y_m2)**2 + \
      0.5 * k3 * (y_m2 - l1 * sp.sin(theta_m2))**2 + \
      0.5 * k4 * (delta_l3)**2 + \
      0.5 * k5 * (delta_l2)**2 + \
      m1 * g * (r + y_m2 + l1 * sp.sin(theta_m2)) + \
      m2 * g * (r + y_m2) + \
      m3 * g * (r + y_m2 - l1 * sp.sin(theta_m2)) + \
      M * g * (r + y_m2 + (delta_l2 + l2) * sp.cos(theta_M))

V = ans.simplify()
sp.pprint(V)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
# M⋅g⋅((r + yₘ₂(t))⋅tan(θ_M) + (l₂⋅tan(θ_M) + y_M(t) - yₘ₂(t))⋅cos(θ_M))⋅tan(θ_M ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪                                 ⎛                                            ↪
# ↪                                 ⎜                                            ↪
# ↪                             2   ⎜                                            ↪
# ↪ ) + 0.5⋅k₅⋅(y_M(t) - yₘ₂(t))  + ⎝g⋅m₁⋅(l₁⋅sin(θₘ₂(t)) + r + yₘ₂(t)) + g⋅m₂⋅( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ r + yₘ₂(t)) + g⋅m₃⋅(-l₁⋅sin(θₘ₂(t)) + r + yₘ₂(t)) + 0.5⋅k₁⋅(l₁⋅sin(θₘ₂(t)) + ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                         2                    ↪
# ↪                                                      tan (θ_M)               ↪
#
# ↪                                                                              ↪
# ↪                                                                         ⎛    ↪
# ↪         2             2                                      2          ⎜    ↪
# ↪  yₘ₂(t))  + 0.5⋅k₂⋅yₘ₂ (t) + 0.5⋅k₃⋅(l₁⋅sin(θₘ₂(t)) - yₘ₂(t))  + 0.5⋅k₄⋅⎝l₃  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪      _______________________________________________________________________ ↪
# ↪     ╱                                               2                        ↪
# ↪ - ╲╱  (l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                              2⎞
# ↪ ____________________________⎞ ⎟
# ↪                           2 ⎟ ⎟    2
# ↪ θₘ₃(t)) - y_M(t) - yₘ₂(t))  ⎠ ⎠⋅tan (θ_M)
# ↪ ─────────────────────────────────────────
# ↪
# ↪

# %%
T_diff_theta_m2_dot = sp.diff(T, sp.diff(theta_m2, t))
T_diff_theta_m3_dot = sp.diff(T, sp.diff(theta_m3, t))
T_diff_y_m2_dot = sp.diff(T, sp.diff(y_m2, t))
T_diff_y_m2_dot = sp.diff(T, sp.diff(y_m2, t))
diff_T_diff_theta_m2_dot = sp.diff(T_diff_theta_m2_dot, t)
diff_T_diff_theta_m3_dot = sp.diff(T_diff_theta_m3_dot, t)
diff_T_diff_y_m2_dot = sp.diff(T_diff_y_m2_dot, t)
diff_T_diff_y_m2_dot = sp.diff(T_diff_y_m2_dot, t)

# %%
T_diff_theta_m2 = sp.diff(T, theta_m2)
T_diff_theta_m3 = sp.diff(T, theta_m3)
T_diff_y_m2 = sp.diff(T, y_m2)
T_diff_y_m2 = sp.diff(T, y_m2)

# %%
D_diff_theta_m2_dot = sp.diff(D, sp.diff(theta_m2, t))
D_diff_theta_m3_dot = sp.diff(D, sp.diff(theta_m3, t))
D_diff_y_m2_dot = sp.diff(D, sp.diff(y_m2, t))
D_diff_y_m2_dot = sp.diff(D, sp.diff(y_m2, t))

# %%
V_diff_theta_m2 = sp.diff(V, theta_m2)
V_diff_theta_m3 = sp.diff(V, theta_m3)
V_diff_y_m2 = sp.diff(V, y_m2)
V_diff_y_m2 = sp.diff(V, y_m2)

# %%
theta_m2_func = diff_T_diff_theta_m2_dot - T_diff_theta_m2 + D_diff_theta_m2_dot + V_diff_theta_m2
theta_m2_func = theta_m2_func.simplify()
sp.pprint(theta_m2_func)
# Out:
#    ⎛                                                                           ↪
#    ⎜       ⎛                                               ⎛               d   ↪
# l₁⋅⎜1.0⋅c₄⋅⎜(l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))⋅⎜l₃⋅cos(θₘ₃(t))⋅──( ↪
#    ⎜       ⎝                                               ⎝               dt  ↪
#    ⎝                                                                           ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪                                                                              ↪
# ↪           ⎛  d            d         ⎞         ⎞                              ↪
# ↪ θₘ₃(t)) + ⎜- ──(y_M(t)) + ──(yₘ₂(t))⎟⋅tan(θ_M)⎟ - (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t) ↪
# ↪           ⎝  dt           dt        ⎠         ⎠                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                      ⎛     d                           d            d        ↪
# ↪ ) - y_M(t) - yₘ₂(t))⋅⎜- l₁⋅──(θₘ₂(t)) + l₃⋅sin(θₘ₃(t))⋅──(θₘ₃(t)) + ──(y_M(t ↪
# ↪                      ⎝     dt                          dt           dt       ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                      _______________________________________________________ ↪
# ↪      d         ⎞⎞   ╱                                               2        ↪
# ↪ )) + ──(yₘ₂(t))⎟⎟⋅╲╱  (l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅ ↪
# ↪      dt        ⎠⎠                                                            ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________                                 ↪
# ↪                                           2                                  ↪
# ↪ θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t))  ⋅(l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                          ⎛        __________________________________________ ↪
# ↪                          ⎜       ╱                                           ↪
# ↪ _M(t) - yₘ₂(t)) - 1.0⋅k₄⋅⎝l₃ - ╲╱  (l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan( ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                  ⎛                                           ↪
# ↪                                  ⎝(l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ ↪
#
# ↪ _________________________________________________________⎞                   ↪
# ↪      2                                                 2 ⎟ ⎛                 ↪
# ↪ θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t))  ⎠⋅⎝(l₃⋅sin(θₘ₃(t))  ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                         3/2                  ↪
# ↪     2                                                 2⎞                     ↪
# ↪ _M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t)) ⎠                     ↪
#
# ↪                                                                              ↪
# ↪                               2                                              ↪
# ↪ + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪     2⎞                                                  ⎛                    ↪
# ↪ (t)) ⎠⋅(l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t)) + ⎝(l₃⋅sin(θₘ₃(t)) + ( ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                            2                                                 ↪
# ↪ -y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t) ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪    3/2 ⎛                                                                     ↪
# ↪  2⎞    ⎜                                                                     ↪
# ↪ ) ⎠   ⋅⎜g⋅m₁⋅cos(θₘ₂(t)) - g⋅m₃⋅cos(θₘ₂(t)) + 1.0⋅k₁⋅(l₁⋅sin(θₘ₂(t)) + yₘ₂(t ↪
# ↪        ⎜                                                                     ↪
# ↪        ⎝                                                                     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ))⋅cos(θₘ₂(t)) + 1.0⋅k₃⋅(l₁⋅sin(θₘ₂(t)) - yₘ₂(t))⋅cos(θₘ₂(t)) + 1.0⋅l₁⋅(m₁ + ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪       2         ⎞⎞
# ↪      d          ⎟⎟
# ↪  m₃)⋅───(θₘ₂(t))⎟⎟
# ↪        2        ⎟⎟
# ↪      dt         ⎠⎠
# ↪ ──────────────────
# ↪
# ↪
# ↪

# %%
theta_m3_func = diff_T_diff_theta_m3_dot - T_diff_theta_m3 + D_diff_theta_m3_dot + V_diff_theta_m3
theta_m3_func = theta_m3_func.simplify()
sp.pprint(theta_m3_func)
# Out:
#                                                                                ↪
#                                                                                ↪
# 1.0⋅l₃⋅((l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))⋅cos(θₘ₃(t)) - (l₁⋅θₘ₂(t ↪
#                                                                                ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪                                                    ⎛                         ↪
# ↪                                                    ⎜   ⎛                     ↪
# ↪ ) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t))⋅sin(θₘ₃(t)))⋅⎜c₄⋅⎜(l₃⋅sin(θₘ₃(t)) + (- ↪
# ↪                                                    ⎝   ⎝                     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                            ⎛               d            ⎛  d            d    ↪
# ↪ y_M(t) + yₘ₂(t))⋅tan(θ_M))⋅⎜l₃⋅cos(θₘ₃(t))⋅──(θₘ₃(t)) + ⎜- ──(y_M(t)) + ──(y ↪
# ↪                            ⎝               dt           ⎝  dt           dt   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪       ⎞         ⎞                                                  ⎛     d   ↪
# ↪ ₘ₂(t))⎟⋅tan(θ_M)⎟ - (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t))⋅⎜- l₁⋅──( ↪
# ↪       ⎠         ⎠                                                  ⎝     dt  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                ⎛             ↪
# ↪                                                                ⎝(l₃⋅sin(θₘ₃( ↪
#
# ↪                                                                    _________ ↪
# ↪                          d            d            d         ⎞⎞   ╱          ↪
# ↪ θₘ₂(t)) + l₃⋅sin(θₘ₃(t))⋅──(θₘ₃(t)) + ──(y_M(t)) + ──(yₘ₂(t))⎟⎟⋅╲╱  (l₃⋅sin( ↪
# ↪                          dt           dt           dt        ⎠⎠              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                   2                                          ↪
# ↪ t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                       2                                      ↪
# ↪ θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪           3/2                                                                ↪
# ↪         2⎞                                                                   ↪
# ↪  yₘ₂(t)) ⎠                                                                   ↪
#
# ↪ ______________      ⎛        _______________________________________________ ↪
# ↪             2       ⎜       ╱                                                ↪
# ↪ t) - yₘ₂(t))   - k₄⋅⎝l₃ - ╲╱  (l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M)) ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________⎞                        ↪
# ↪ 2                                                 2 ⎟ ⎛                      ↪
# ↪   + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t))  ⎠⋅⎝(l₃⋅sin(θₘ₃(t)) + (-y ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                          2                                                 2 ↪
# ↪ _M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t))  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪  ⎞
# ↪ ⎞⎟
# ↪ ⎠⎟
# ↪  ⎠
# ↪ ──
# ↪
# ↪
# ↪

# %%
y_m2_func = diff_T_diff_y_m2_dot - T_diff_y_m2 + D_diff_y_m2_dot + V_diff_y_m2
y_m2_func = y_m2_func.simplify()
sp.pprint(y_m2_func)
# Out:
#     ⎛    2            ⎛ 2             2         ⎞                         ⎞    ↪
#     ⎜   d             ⎜d             d          ⎟                   2     ⎟ ⎛  ↪
# 1.0⋅⎜m₂⋅───(yₘ₂(t)) - ⎜───(y_M(t)) - ───(yₘ₂(t))⎟⋅(m₁ + m₂ + m₃)⋅tan (θ_M)⎟⋅⎝( ↪
#     ⎜     2           ⎜  2             2        ⎟                         ⎟    ↪
#     ⎝   dt            ⎝dt            dt         ⎠                         ⎠    ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪                                                                              ↪
# ↪                                              2                               ↪
# ↪ l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                      3/2             ⎛                                       ↪
# ↪                    2⎞       2        ⎜  ⎛    ⎛              2     ⎞          ↪
# ↪  - y_M(t) - yₘ₂(t)) ⎠   ⋅tan (θ_M) + ⎝- ⎝M⋅g⋅⎝sin(θ_M) - tan (θ_M)⎠ + 1.0⋅k₅ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                        _____________________________________________________ ↪
# ↪                   ⎞   ╱                                               2      ↪
# ↪ ⋅(y_M(t) - yₘ₂(t))⎠⋅╲╱  (l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ______________________________________________       ⎛     ⎛        ________ ↪
# ↪                                             2        ⎜     ⎜       ╱         ↪
# ↪ ₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t))   + 1.0⋅⎝- k₄⋅⎝l₃ - ╲╱  (l₃⋅sin ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                        2                                     ↪
# ↪ (θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _______________⎞                                                             ↪
# ↪              2 ⎟                                                             ↪
# ↪ (t) - yₘ₂(t))  ⎠⋅(-l₁⋅θₘ₂(t) - l₃⋅cos(θₘ₃(t)) + (l₃⋅sin(θₘ₃(t)) + (-y_M(t) + ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                     ________________________ ↪
# ↪                                                    ╱                         ↪
# ↪  yₘ₂(t))⋅tan(θ_M))⋅tan(θ_M) + y_M(t) + yₘ₂(t)) + ╲╱  (l₃⋅sin(θₘ₃(t)) + (-y_M ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________________________________________________________________________  ↪
# ↪                        2                                                 2   ↪
# ↪ (t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t))  ⋅ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ (g⋅m₁ + g⋅m₂ + g⋅m₃ + k₁⋅l₁⋅sin(θₘ₂(t)) + k₁⋅yₘ₂(t) + k₂⋅yₘ₂(t) - k₃⋅l₁⋅sin( ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪     ⎛                                              2                         ↪
# ↪     ⎝(l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θ ↪
#
# ↪                     ⎞          ⎞                                             ↪
# ↪                     ⎟    2     ⎟ ⎛                                           ↪
# ↪ θₘ₂(t)) + k₃⋅yₘ₂(t))⎠⋅tan (θ_M)⎠⋅⎝(l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                            3/2                                               ↪
# ↪                          2⎞       2                                          ↪
# ↪ ₘ₃(t)) - y_M(t) - yₘ₂(t)) ⎠   ⋅tan (θ_M)                                     ↪
#
# ↪                                                                              ↪
# ↪     2                                                 2⎞       ⎛   ⎛         ↪
# ↪ _M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t)) ⎠ + 1.0⋅⎜c₄⋅⎜(l₃⋅sin( ↪
# ↪                                                                ⎝   ⎝         ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                        ⎛               d            ⎛  d     ↪
# ↪ θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))⋅⎜l₃⋅cos(θₘ₃(t))⋅──(θₘ₃(t)) + ⎜- ──(y_ ↪
# ↪                                        ⎝               dt           ⎝  dt    ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪         d         ⎞         ⎞                                                ↪
# ↪ M(t)) + ──(yₘ₂(t))⎟⋅tan(θ_M)⎟ - (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t ↪
# ↪         dt        ⎠         ⎠                                                ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪    ⎛     d                           d            d            d         ⎞⎞  ↪
# ↪ ))⋅⎜- l₁⋅──(θₘ₂(t)) + l₃⋅sin(θₘ₃(t))⋅──(θₘ₃(t)) + ──(y_M(t)) + ──(yₘ₂(t))⎟⎟⋅ ↪
# ↪    ⎝     dt                          dt           dt           dt        ⎠⎠  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ (-l₁⋅θₘ₂(t) - l₃⋅cos(θₘ₃(t)) + (l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M) ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                  2           ⎛                               ↪
# ↪ )⋅tan(θ_M) + y_M(t) + yₘ₂(t))⋅tan (θ_M) - c₅⋅⎝(l₃⋅sin(θₘ₃(t)) + (-y_M(t) + y ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                 2                                                 2⎞ ⎛d      ↪
# ↪ ₘ₂(t))⋅tan(θ_M))  + (l₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t)) ⎠⋅⎜──(y_M ↪
# ↪                                                                      ⎝dt     ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                        _____________________________________________________ ↪
# ↪        d         ⎞⎞   ╱                                               2      ↪
# ↪ (t)) - ──(yₘ₂(t))⎟⎟⋅╲╱  (l₃⋅sin(θₘ₃(t)) + (-y_M(t) + yₘ₂(t))⋅tan(θ_M))  + (l ↪
# ↪        dt        ⎠⎠                                                          ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ______________________________________________
# ↪                                             2
# ↪ ₁⋅θₘ₂(t) + l₃⋅cos(θₘ₃(t)) - y_M(t) - yₘ₂(t))
# ↪
# ↪
# ↪ ──────────────────────────────────────────────
# ↪
# ↪
# ↪

# %%
y_m2_func = diff_T_diff_y_m2_dot - T_diff_y_m2 + D_diff_y_m2_dot + V_diff_y_m2
y_m2_func = y_m2_func.simplify()
sp.pprint(y_m2_func)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 2
#       1 y_m2_func = diff_T_diff_y_m2_dot - T_diff_y_m2 + D_diff_y_m2_dot + V_diff_y_m2
# ----> 2 y_m2_func = y_m2_func.simplify()
#       3 sp.pprint(y_m2_func)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/core/basic.py:1936, in Basic.simplify(self, **kwargs)
#    1934 """See the simplify function in sympy.simplify"""
#    1935 from sympy.simplify.simplify import simplify
# -> 1936 return simplify(self, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/simplify/simplify.py:699, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     696     expr = besselsimp(expr)
#     698 if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 699     expr = trigsimp(expr, deep=True)
#     701 if expr.has(log):
#     702     expr = shorter(expand_log(expr, deep=True), logcombine(expr))
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/simplify/trigsimp.py:565, in trigsimp(expr, inverse, **opts)
#     554     return trigsimp_groebner(new, **opts)
#     556 trigsimpfunc = {
#     557     'fu': (lambda x: fu(x, **opts)),
#     558     'matching': (lambda x: futrig(x)),
#    (...)
#     562     'old': lambda x: trigsimp_old(x, **opts),
#     563                }[method]
# --> 565 expr_simplified = trigsimpfunc(expr)
#     566 if inverse:
#     567     expr_simplified = _trigsimp_inverse(expr_simplified)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/simplify/trigsimp.py:558, in trigsimp.<locals>.<lambda>(x)
#     553         return new
#     554     return trigsimp_groebner(new, **opts)
#     556 trigsimpfunc = {
#     557     'fu': (lambda x: fu(x, **opts)),
# --> 558     'matching': (lambda x: futrig(x)),
#     559     'groebner': (lambda x: groebnersimp(x, **opts)),
#     560     'combined': (lambda x: futrig(groebnersimp(x,
#     561                            polynomial=True, hints=[2, tan]))),
#     562     'old': lambda x: trigsimp_old(x, **opts),
#     563                }[method]
#     565 expr_simplified = trigsimpfunc(expr)
#     566 if inverse:
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/simplify/trigsimp.py:1159, in futrig(e, hyper, **kwargs)
#    1156     return e
#    1158 old = e
# -> 1159 e = bottom_up(e, _futrig)
#    1161 if hyper and e.has(HyperbolicFunction):
#    1162     e, f = hyper_as_trig(e)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/core/traversal.py:230, in bottom_up(rv, F, atoms, nonbasic)
#     228 if args is not None:
#     229     if args:
# --> 230         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     231         if args != rv.args:
#     232             rv = rv.func(*args)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/core/traversal.py:230, in <listcomp>(.0)
#     228 if args is not None:
#     229     if args:
# --> 230         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     231         if args != rv.args:
#     232             rv = rv.func(*args)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/core/traversal.py:230, in bottom_up(rv, F, atoms, nonbasic)
#     228 if args is not None:
#     229     if args:
# --> 230         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     231         if args != rv.args:
#     232             rv = rv.func(*args)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/core/traversal.py:230, in <listcomp>(.0)
#     228 if args is not None:
#     229     if args:
# --> 230         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     231         if args != rv.args:
#     232             rv = rv.func(*args)
#
#     [... skipping similar frames: <listcomp> at line 230 (2 times), bottom_up at line 230 (2 times)]
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/core/traversal.py:230, in bottom_up(rv, F, atoms, nonbasic)
#     228 if args is not None:
#     229     if args:
# --> 230         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     231         if args != rv.args:
#     232             rv = rv.func(*args)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/core/traversal.py:230, in <listcomp>(.0)
#     228 if args is not None:
#     229     if args:
# --> 230         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     231         if args != rv.args:
#     232             rv = rv.func(*args)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/core/traversal.py:233, in bottom_up(rv, F, atoms, nonbasic)
#     231     if args != rv.args:
#     232         rv = rv.func(*args)
# --> 233     rv = F(rv)
#     234 elif atoms:
#     235     rv = F(rv)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/simplify/trigsimp.py:1226, in _futrig(e)
#    1187 trigs = lambda x: x.has(TrigonometricFunction)
#    1189 tree = [identity,
#    1190     (
#    1191     TR3,  # canonical angles
#    (...)
#    1224         factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1225     )]
# -> 1226 e = greedy(tree, objective=Lops)(e)
#    1228 if coeff is not None:
#    1229     e = coeff * e
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/strategies/core.py:150, in minimize.<locals>.minrule(expr)
#     149 def minrule(expr: _S) -> _T:
# --> 150     return min([rule(expr) for rule in rules], key=objective)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/strategies/core.py:150, in <listcomp>(.0)
#     149 def minrule(expr: _S) -> _T:
# --> 150     return min([rule(expr) for rule in rules], key=objective)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/strategies/core.py:64, in chain.<locals>.chain_rl(expr)
#      62 def chain_rl(expr: _T) -> _T:
#      63     for rule in rules:
# ---> 64         expr = rule(expr)
#      65     return expr
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/simplify/trigsimp.py:1203, in _futrig.<locals>.<lambda>(x)
#    1186 Lops = lambda x: (L(x), x.count_ops(), _nodes(x), len(x.args), x.is_Add)
#    1187 trigs = lambda x: x.has(TrigonometricFunction)
#    1189 tree = [identity,
#    1190     (
#    1191     TR3,  # canonical angles
#    1192     TR1,  # sec-csc -> cos-sin
#    1193     TR12,  # expand tan of sum
#    1194     lambda x: _eapply(factor, x, trigs),
#    1195     TR2,  # tan-cot -> sin-cos
#    1196     [identity, lambda x: _eapply(_mexpand, x, trigs)],
#    1197     TR2i,  # sin-cos ratio -> tan
#    1198     lambda x: _eapply(lambda i: factor(i.normal()), x, trigs),
#    1199     TR14,  # factored identities
#    1200     TR5,  # sin-pow -> cos_pow
#    1201     TR10,  # sin-cos of sums -> sin-cos prod
#    1202     TR11, _TR11, TR6, # reduce double angles and rewrite cos pows
# -> 1203     lambda x: _eapply(factor, x, trigs),
#    1204     TR14,  # factored powers of identities
#    1205     [identity, lambda x: _eapply(_mexpand, x, trigs)],
#    1206     TR10i,  # sin-cos products > sin-cos of sums
#    1207     TRmorrie,
#    1208     [identity, TR8],  # sin-cos products -> sin-cos of sums
#    1209     [identity, lambda x: TR2i(TR2(x))],  # tan -> sin-cos -> tan
#    1210     [
#    1211         lambda x: _eapply(expand_mul, TR5(x), trigs),
#    1212         lambda x: _eapply(
#    1213             expand_mul, TR15(x), trigs)], # pos/neg powers of sin
#    1214     [
#    1215         lambda x:  _eapply(expand_mul, TR6(x), trigs),
#    1216         lambda x:  _eapply(
#    1217             expand_mul, TR16(x), trigs)], # pos/neg powers of cos
#    1218     TR111,  # tan, sin, cos to neg power -> cot, csc, sec
#    1219     [identity, TR2i],  # sin-cos ratio to tan
#    1220     [identity, lambda x: _eapply(
#    1221         expand_mul, TR22(x), trigs)],  # tan-cot to sec-csc
#    1222     TR1, TR2, TR2i,
#    1223     [identity, lambda x: _eapply(
#    1224         factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1225     )]
#    1226 e = greedy(tree, objective=Lops)(e)
#    1228 if coeff is not None:
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/simplify/trigsimp.py:1250, in _eapply(func, e, cond)
#    1248     return e
#    1249 if _is_Expr(e) or not e.args:
# -> 1250     return func(e)
#    1251 return e.func(*[
#    1252     _eapply(func, ei) if (cond is None or cond(ei)) else ei
#    1253     for ei in e.args])
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/polytools.py:6577, in factor(f, deep, *gens, **args)
#    6574     return f.xreplace(partials)
#    6576 try:
# -> 6577     return _generic_factor(f, gens, args, method='factor')
#    6578 except PolynomialError:
#    6579     if not f.is_commutative:
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/polytools.py:6258, in _generic_factor(expr, gens, args, method)
#    6256 opt = options.build_options(gens, args)
#    6257 opt['fraction'] = fraction
# -> 6258 return _symbolic_factor(sympify(expr), opt, method)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/polytools.py:6198, in _symbolic_factor(expr, opt, method)
#    6196     if hasattr(expr,'_eval_factor'):
#    6197         return expr._eval_factor()
# -> 6198     coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    6199     return _keep_coeff(coeff, _factors_product(factors))
#    6200 elif hasattr(expr, 'args'):
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/polytools.py:6163, in _symbolic_factor_list(expr, opt, method)
#    6160 else:
#    6161     func = getattr(poly, method + '_list')
# -> 6163     _coeff, _factors = func()
#    6164     if _coeff is not S.One:
#    6165         if exp.is_Integer:
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/polytools.py:3378, in Poly.factor_list(f)
#    3376 if hasattr(f.rep, 'factor_list'):
#    3377     try:
# -> 3378         coeff, factors = f.rep.factor_list()
#    3379     except DomainError:
#    3380         if f.degree() == 0:
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/polyclasses.py:1637, in DMP_Python.factor_list(f)
#    1635 def factor_list(f):
#    1636     """Returns a list of irreducible factors of ``f``. """
# -> 1637     coeff, factors = dmp_factor_list(f._rep, f.lev, f.dom)
#    1638     return coeff, [ (f.per(g), k) for g, k in factors ]
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/factortools.py:1569, in dmp_factor_list(f, u, K0)
#    1567 if K.is_ZZ:
#    1568     levels, f, v = dmp_exclude(f, u, K)
# -> 1569     coeff, factors = dmp_zz_factor(f, v, K)
#    1571     for i, (f, k) in enumerate(factors):
#    1572         factors[i] = (dmp_include(f, levels, v, K), k)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/factortools.py:1189, in dmp_zz_factor(f, u, K)
#    1187 if dmp_degree(g, u) > 0:
#    1188     g = dmp_sqf_part(g, u, K)
# -> 1189     H = dmp_zz_wang(g, u, K)
#    1190     factors = dmp_trial_division(f, H, u, K)
#    1192 for g, k in dmp_zz_factor(G, u - 1, K)[1]:
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/factortools.py:1112, in dmp_zz_wang(f, u, K, mod, seed)
#    1110 try:
#    1111     f, H, LC = dmp_zz_wang_lead_coeffs(f, T, cs, E, H, A, u, K)
# -> 1112     factors = dmp_zz_wang_hensel_lifting(f, H, LC, A, p, u, K)
#    1113 except ExtraneousFactors:  # pragma: no cover
#    1114     if query('EEZ_RESTART_IF_NEEDED'):
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/factortools.py:982, in dmp_zz_wang_hensel_lifting(f, H, LC, A, p, u, K)
#     979                 h = dmp_add_mul(h, dmp_raise(t, 1, w - 1, K), M, w, K)
#     980                 H[i] = dmp_ground_trunc(h, p, w, K)
# --> 982             h = dmp_sub(s, dmp_expand(H, w, K), w, K)
#     983             c = dmp_ground_trunc(h, p, w, K)
#     985 if dmp_expand(H, u, K) != f:
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/densearith.py:1873, in dmp_expand(polys, u, K)
#    1870 f = polys[0]
#    1872 for g in polys[1:]:
# -> 1873     f = dmp_mul(f, g, u, K)
#    1875 return f
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
#     [... skipping similar frames: dmp_mul at line 828 (7 times)]
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/densearith.py:563, in dmp_add(f, g, u, K)
#     549 """
#     550 Add dense polynomials in ``K[X]``.
#     551
#    (...)
#     560
#     561 """
#     562 if not u:
# --> 563     return dup_add(f, g, K)
#     565 df = dmp_degree(f, u)
#     567 if df < 0:
#
# File /opt/homebrew/lib/python3.10/site-packages/sympy/polys/densearith.py:536, in dup_add(f, g, K)
#     533 dg = dup_degree(g)
#     535 if df == dg:
# --> 536     return dup_strip([ a + b for a, b in zip(f, g) ])
#     537 else:
#     538     k = abs(df - dg)
#
# KeyboardInterrupt:

# %%
Q1 = sp.symbols('Q1')
Q2 = sp.symbols('Q2')
Q3 = sp.symbols('Q3')
Q4 = sp.symbols('Q4')

# %%
function1 = theta_m2_func - Q1
solution1 = sp.solve(function1, sp.diff(sp.diff(theta_m2, t), t))
solution1_simple = solution1[0].simplify()
sp.pprint(solution1_simple)
# Out:
#                                                                                ↪
#        ⎛       2    2                                                        2 ↪
# 1.0⋅Q₁⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ↪
#                                                                                ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪  3/2                  ______________________________________________________ ↪
# ↪ ⎞                4   ╱        2    2                                         ↪
# ↪ ⎠    - 0.25⋅c₄⋅l₁ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________                                        __________________ ↪
# ↪                 2     2    d                      3      ╱        2    2     ↪
# ↪ ₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂ (t)⋅──(θₘ₂(t)) + 0.25⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃ ↪
# ↪                            dt                                                ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ______________________________________________________                       ↪
# ↪                                                     2     2                d ↪
# ↪ (t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂ (t)⋅sin(θₘ₃(t))⋅─ ↪
# ↪                                                                            d ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                              _______________________________________________ ↪
# ↪                      3      ╱        2    2                                  ↪
# ↪ ─(θₘ₃(t)) - 0.5⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l ↪
# ↪ t                                                                            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _________________________                                               ____ ↪
# ↪                        2                     d                     3   ╱     ↪
# ↪ ₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅cos(θₘ₃(t))⋅──(θₘ₂(t)) + 0.5⋅c₄⋅l₁ ⋅╲╱  0.2 ↪
# ↪                                              dt                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________         ↪
# ↪     2    2                                                        2     2    ↪
# ↪ 5⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂ (t) ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                             ________________________________________________ ↪
# ↪  d                     3   ╱        2    2                                   ↪
# ↪ ⋅──(yₘ₂(t)) + 1.0⋅c₄⋅l₁ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃ ↪
# ↪  dt                                                                          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________________                                                ____ ↪
# ↪                       2                d                       2   2   ╱     ↪
# ↪ ⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂(t)⋅──(θₘ₂(t)) - 0.125⋅c₄⋅l₁ ⋅l₃ ⋅╲╱  0.2 ↪
# ↪                                        dt                                    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________         ↪
# ↪     2    2                                                        2          ↪
# ↪ 5⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                 ____________________________ ↪
# ↪                 d                      2   2   ╱        2    2               ↪
# ↪ sin(2.0⋅θₘ₃(t))⋅──(θₘ₃(t)) - 0.25⋅c₄⋅l₁ ⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0. ↪
# ↪                 dt                                                           ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________                                 ↪
# ↪                                           2     2         d                  ↪
# ↪ 5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅cos (θₘ₃(t))⋅──(θₘ₂(t)) + 0.25⋅ ↪
# ↪                                                           dt                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪               ______________________________________________________________ ↪
# ↪      2   2   ╱        2    2                                                 ↪
# ↪ c₄⋅l₁ ⋅l₃ ⋅╲╱  0.25⋅l₁ ⋅θₘ₂ (t) + 0.5⋅l₁⋅l₃⋅θₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ₂(t)⋅y ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________________________________________________                          ↪
# ↪                2                              2                            d ↪
# ↪ ₘ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂(t)⋅cos(θₘ₃(t)) + yₘ₂ (t) ⋅θₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅─ ↪
# ↪                                                                            d ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                              _______________________________________________ ↪
# ↪                      2      ╱        2    2                                  ↪
# ↪ ─(θₘ₃(t)) - 1.0⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l ↪
# ↪ t                                                                            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _________________________                                                    ↪
# ↪                        2                            d                     2  ↪
# ↪ ₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂(t)⋅sin(θₘ₃(t))⋅──(θₘ₃(t)) + 1.0⋅c₄⋅l₁ ⋅ ↪
# ↪                                                     dt                       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪       ______________________________________________________________________ ↪
# ↪      ╱        2    2                                                         ↪
# ↪ l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __                                                  ________________________ ↪
# ↪ 2                     d                     2      ╱        2    2           ↪
# ↪   ⋅θₘ₂(t)⋅cos(θₘ₃(t))⋅──(yₘ₂(t)) + 1.0⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + ↪
# ↪                       dt                                                     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________________________________________                             ↪
# ↪                                               2                     d        ↪
# ↪  (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅cos(θₘ₃(t))⋅──(θₘ₂(t ↪
# ↪                                                                     dt       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                    _________________________________________________________ ↪
# ↪               2   ╱        2    2                                            ↪
# ↪ )) - 2.0⋅c₄⋅l₁ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _______________                                          ___________________ ↪
# ↪              2                d                     2   ╱        2    2      ↪
# ↪ t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂(t)⋅──(yₘ₂(t)) - 1.0⋅c₄⋅l₁ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃( ↪
# ↪                               dt                                             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____________________________________________________                        ↪
# ↪                                                    2     2    d              ↪
# ↪ t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂ (t)⋅──(θₘ₂(t)) + 0 ↪
# ↪                                                               dt             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                  ___________________________________________________________ ↪
# ↪             3   ╱        2    2                                              ↪
# ↪ .25⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t) ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____________                                                          _____ ↪
# ↪            2                 2         d                          3   ╱      ↪
# ↪ ) - yₘ₂(t))  ⋅sin(θₘ₃(t))⋅cos (θₘ₃(t))⋅──(θₘ₃(t)) - 0.125⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25 ↪
# ↪                                        dt                                    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________________________________________________________________          ↪
# ↪    2    2                                                        2           ↪
# ↪ ⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅sin(2.0⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                    _________________________ ↪
# ↪                     d                         2   ╱        2    2            ↪
# ↪ θₘ₃(t))⋅cos(θₘ₃(t))⋅──(θₘ₃(t)) + 0.25⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) +  ↪
# ↪                     dt                                                       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _______________________________________________                              ↪
# ↪                                              2                         d     ↪
# ↪ (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(θₘ ↪
# ↪                                                                        dt    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                          ___________________________________________________ ↪
# ↪                     2   ╱        2    2                                      ↪
# ↪ ₃(t)) + 0.5⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅co ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____________________                                            ___________ ↪
# ↪                    2     2         d                        2   ╱        2   ↪
# ↪ s(θₘ₃(t)) - yₘ₂(t))  ⋅cos (θₘ₃(t))⋅──(yₘ₂(t)) - 0.5⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₁ ⋅θ ↪
# ↪                                    dt                                        ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪   2                                                               2          ↪
# ↪ ₘ₂ (t) + 0.5⋅l₁⋅l₃⋅θₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ₂(t)⋅yₘ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪         2           ⎛       2    2                                           ↪
# ↪       l₁ ⋅(m₁ + m₃)⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃ ↪
#
# ↪ __________________________                                                   ↪
# ↪                      2                            d                          ↪
# ↪ (t)⋅cos(θₘ₃(t)) + yₘ₂ (t) ⋅yₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(θₘ₃(t)) + 1.0⋅c₄⋅l₁⋅l₃⋅ ↪
# ↪                                                   dt                         ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                 3/2                                                          ↪
# ↪               2⎞                                                             ↪
# ↪ (t)) - yₘ₂(t)) ⎠                                                             ↪
#
# ↪    ________________________________________________________________________  ↪
# ↪   ╱        2    2                                                        2   ↪
# ↪ ╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                  ___________________________ ↪
# ↪    2                d                           ╱        2    2              ↪
# ↪ yₘ₂ (t)⋅sin(θₘ₃(t))⋅──(θₘ₃(t)) - 2.0⋅c₄⋅l₁⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0 ↪
# ↪                     dt                                                       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____________________________________________                                ↪
# ↪                                            2                     d           ↪
# ↪ .5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅cos(θₘ₃(t))⋅──(yₘ₂(t))  ↪
# ↪                                                                  dt          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                _____________________________________________________________ ↪
# ↪               ╱        2    2                                                ↪
# ↪ + 2.0⋅c₄⋅l₁⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t))  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________                                                                  ↪
# ↪          2     2    d                        ⎛       2    2                  ↪
# ↪ - yₘ₂(t))  ⋅yₘ₂ (t)⋅──(yₘ₂(t)) - 1.0⋅g⋅l₁⋅m₁⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l ↪
# ↪                     dt                                                       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                          3/2                                 ↪
# ↪                                        2⎞                              ⎛     ↪
# ↪ ₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅cos(θₘ₂(t)) + 1.0⋅g⋅l₁⋅m₃⋅⎝0.25 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                    3/2       ↪
# ↪    2    2                                                        2⎞          ↪
# ↪ ⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅cos(θ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                   2 ⎛       2    2                                           ↪
# ↪ ₘ₂(t)) - 0.5⋅k₁⋅l₁ ⋅⎝0.25⋅l₁ ⋅θₘ₂ (t) + 0.5⋅l₁⋅l₃⋅θₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                          3/2                 ↪
# ↪                      2                              2   ⎞                    ↪
# ↪ ₂(t)⋅yₘ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂(t)⋅cos(θₘ₃(t)) + yₘ₂ (t)⎠   ⋅sin(2.0⋅θₘ₂(t)) ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪              ⎛       2    2                                                  ↪
# ↪  - 1.0⋅k₁⋅l₁⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) -  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪          3/2                                                                 ↪
# ↪        2⎞                                  2 ⎛       2    2                  ↪
# ↪ yₘ₂(t)) ⎠   ⋅yₘ₂(t)⋅cos(θₘ₂(t)) - 0.5⋅k₃⋅l₁ ⋅⎝0.25⋅l₁ ⋅θₘ₂ (t) + 0.5⋅l₁⋅l₃⋅θ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                               2                              ↪
# ↪ ₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ₂(t)⋅yₘ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂(t)⋅cos(θₘ₃(t)) + yₘ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪       3/2                                                                    ↪
# ↪  2   ⎞                                ⎛       2    2                         ↪
# ↪ ₂ (t)⎠   ⋅sin(2.0⋅θₘ₂(t)) + 1.0⋅k₃⋅l₁⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                   3/2                                        ↪
# ↪                                 2⎞                                    2   3  ↪
# ↪ ) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅yₘ₂(t)⋅cos(θₘ₂(t)) + 0.125⋅k₄⋅l₁ ⋅l₃ ⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                          ___________________________________ ↪
# ↪           2                     2   2   ╱        2    2                      ↪
# ↪ θₘ₂(t)⋅sin (θₘ₃(t)) - 0.25⋅k₄⋅l₁ ⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____________________________________                                        ↪
# ↪                                    2            2                    2       ↪
# ↪ ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅sin (θₘ₃(t)) + 0.5⋅k₄⋅l₁ ⋅l₃⋅(0 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                     ________ ↪
# ↪                                            2                   2   ╱         ↪
# ↪ .5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅θₘ₂(t) - 1.0⋅k₄⋅l₁ ⋅╲╱  0.25⋅l₃ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________________________________________________________             ↪
# ↪ 2    2                                                        2              ↪
# ↪  ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅(0.5⋅l₁⋅θₘ₂ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                   2                        4    2            ↪
# ↪ (t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅θₘ₂(t) + 0.125⋅k₄⋅l₁⋅l₃ ⋅sin (θₘ₃(t))⋅co ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                               ______________________________________________ ↪
# ↪                          3   ╱        2    2                                 ↪
# ↪ s(θₘ₃(t)) - 0.25⋅k₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________                                                   ↪
# ↪                         2     2                                    3         ↪
# ↪ l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅sin (θₘ₃(t))⋅cos(θₘ₃(t)) - 0.25⋅k₄⋅l₁⋅l₃ ⋅yₘ₂(t)⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                 ____________________________________________ ↪
# ↪    2                       2   ╱        2    2                               ↪
# ↪ sin (θₘ₃(t)) + 0.5⋅k₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0. ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________                                                 ↪
# ↪                           2            2                       2             ↪
# ↪ 5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅sin (θₘ₃(t)) + 0.5⋅k₄⋅l₁⋅l₃ ⋅(0.5⋅l₁⋅θₘ₂ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                   __________ ↪
# ↪                                   2                              ╱        2  ↪
# ↪ (t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅cos(θₘ₃(t)) - 1.0⋅k₄⋅l₁⋅l₃⋅╲╱  0.25⋅l₃ ⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ______________________________________________________________               ↪
# ↪    2                                                        2                ↪
# ↪ sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅(0.5⋅l₁⋅θₘ₂(t ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                 2                                            ↪
# ↪ ) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅cos(θₘ₃(t)) - 1.0⋅k₄⋅l₁⋅l₃⋅(0.5⋅l₁⋅θₘ₂(t)  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                       ______________________ ↪
# ↪                               2                      ╱        2    2         ↪
# ↪ + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅yₘ₂(t) + 2.0⋅k₄⋅l₁⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________________________                           ↪
# ↪                                                 2                            ↪
# ↪  + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅(0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅c ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪
# ↪                     2
# ↪ os(θₘ₃(t)) - yₘ₂(t)) ⋅yₘ₂(t)
# ↪
# ↪ ────────────────────────────
# ↪
# ↪
# ↪

# %%
function2 = theta_m3_func - Q2
solution2 = sp.solve(function2, sp.diff(theta_m3, t))
solution2_simple = solution2[0].simplify()
sp.pprint(solution2_simple)
# Out:
#                                                                                ↪
#        ⎛       2    2                                                        2 ↪
# 1.0⋅Q₂⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ↪
#                                                                                ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪  3/2                     ___________________________________________________ ↪
# ↪ ⎞                3      ╱        2    2                                      ↪
# ↪ ⎠    + 0.25⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅co ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____________________                                                      _ ↪
# ↪                    2     2                d                       2   2   ╱  ↪
# ↪ s(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂ (t)⋅sin(θₘ₃(t))⋅──(θₘ₂(t)) + 0.125⋅c₄⋅l₁ ⋅l₃ ⋅╲╱   ↪
# ↪                                           dt                                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪        2    2                                                                ↪
# ↪ 0.25⋅l₁ ⋅θₘ₂ (t) + 0.5⋅l₁⋅l₃⋅θₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ₂(t)⋅yₘ₂(t) + 0.25⋅l₃ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________                                         ↪
# ↪ 2                              2                            d                ↪
# ↪   - l₃⋅yₘ₂(t)⋅cos(θₘ₃(t)) + yₘ₂ (t) ⋅θₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(θₘ₂(t)) - 0.5 ↪
# ↪                                                             dt               ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪               ______________________________________________________________ ↪
# ↪       2      ╱        2    2                                                 ↪
# ↪ ⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________                                                   _______________ ↪
# ↪         2     2                d                     2      ╱        2    2  ↪
# ↪  yₘ₂(t))  ⋅θₘ₂ (t)⋅sin(θₘ₃(t))⋅──(yₘ₂(t)) - 1.0⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin ( ↪
# ↪                                dt                                            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _________________________________________________________                    ↪
# ↪                                                        2                     ↪
# ↪ θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂(t)⋅sin( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                        _____________________________________ ↪
# ↪         d                         2   ╱        2    2                        ↪
# ↪ θₘ₃(t))⋅──(θₘ₂(t)) - 0.25⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₁ ⋅θₘ₂ (t) + 0.5⋅l₁⋅l₃⋅θₘ₂(t)⋅ ↪
# ↪         dt                                                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                         2                              2     ↪
# ↪ cos(θₘ₃(t)) - l₁⋅θₘ₂(t)⋅yₘ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂(t)⋅cos(θₘ₃(t)) + yₘ₂ (t)  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                        _____________________ ↪
# ↪                         d                         2   ╱        2    2        ↪
# ↪ ⋅θₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(yₘ₂(t)) - 0.25⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₁ ⋅θₘ₂ (t) + 0 ↪
# ↪                         dt                                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                         2                    ↪
# ↪ .5⋅l₁⋅l₃⋅θₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ₂(t)⋅yₘ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂(t)⋅cos(θₘ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________                                                     _______ ↪
# ↪            2                            d                           ╱        ↪
# ↪ ₃(t)) + yₘ₂ (t) ⋅yₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(θₘ₂(t)) + 2.0⋅c₄⋅l₁⋅l₃⋅╲╱  0.25⋅l ↪
# ↪                                         dt                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _________________________________________________________________            ↪
# ↪  2    2                                                        2             ↪
# ↪ ₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                              _______________________________ ↪
# ↪                 d                           ╱        2    2                  ↪
# ↪ (t)⋅sin(θₘ₃(t))⋅──(yₘ₂(t)) + 1.0⋅c₄⋅l₁⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l ↪
# ↪                 dt                                                           ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                          ___________________________________ ↪
# ↪           2                         2   ╱        2    2                      ↪
# ↪      c₄⋅l₃ ⋅(0.5⋅l₁⋅θₘ₂(t) - yₘ₂(t)) ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ ↪
#
# ↪ _________________________________________                                    ↪
# ↪                                        2     2                d              ↪
# ↪ ₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂ (t)⋅sin(θₘ₃(t))⋅──(θₘ₂(t)) + 0 ↪
# ↪                                                               dt             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ _____________________________________                                        ↪
# ↪                                    2     2                                   ↪
# ↪ ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅sin (θₘ₃(t))                           ↪
#
# ↪              _______________________________________________________________ ↪
# ↪         2   ╱        2    2                                                  ↪
# ↪ .5⋅c₄⋅l₃ ⋅╲╱  0.25⋅l₁ ⋅θₘ₂ (t) + 0.5⋅l₁⋅l₃⋅θₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ₂(t)⋅yₘ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________________________                           ↪
# ↪               2                              2                            d  ↪
# ↪ ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂(t)⋅cos(θₘ₃(t)) + yₘ₂ (t) ⋅yₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅── ↪
# ↪                                                                           dt ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                         ____________________________________________________ ↪
# ↪                        ╱        2    2                                       ↪
# ↪ (yₘ₂(t)) - 2.0⋅c₄⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________                                                         ↪
# ↪                   2     2                d                          4        ↪
# ↪ (θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂ (t)⋅sin(θₘ₃(t))⋅──(yₘ₂(t)) - 0.125⋅k₄⋅l₁⋅l₃ ⋅θₘ₂(t) ↪
# ↪                                          dt                                  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                   __________________________________________ ↪
# ↪     3                        3   ╱        2    2                             ↪
# ↪ ⋅sin (θₘ₃(t)) + 0.25⋅k₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) +  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ______________________________                                               ↪
# ↪                             2            3                       2           ↪
# ↪ 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅sin (θₘ₃(t)) - 0.5⋅k₄⋅l₁⋅l₃ ⋅(0.5⋅l₁⋅θ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                            _ ↪
# ↪                                     2                                     ╱  ↪
# ↪ ₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅θₘ₂(t)⋅sin(θₘ₃(t)) + 1.0⋅k₄⋅l₁⋅l₃⋅╲╱   ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _______________________________________________________________________      ↪
# ↪        2    2                                                        2       ↪
# ↪ 0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅(0.5 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                          2                                4  ↪
# ↪ ⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅θₘ₂(t)⋅sin(θₘ₃(t)) + 0.25⋅k₄⋅l₃ ⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                     ________________________________________ ↪
# ↪           3                    3   ╱        2    2                           ↪
# ↪ yₘ₂(t)⋅sin (θₘ₃(t)) - 0.5⋅k₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t)  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________________________                                             ↪
# ↪                               2            3                    2            ↪
# ↪ + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅sin (θₘ₃(t)) + 1.0⋅k₄⋅l₃ ⋅(0.5⋅l₁⋅θₘ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                        _____ ↪
# ↪                                    2                                  ╱      ↪
# ↪ ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅yₘ₂(t)⋅sin(θₘ₃(t)) - 2.0⋅k₄⋅l₃⋅╲╱  0.25 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________________________________________________________________          ↪
# ↪    2    2                                                        2           ↪
# ↪ ⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅(0.5⋅l₁⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪
# ↪                                      2
# ↪ θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅yₘ₂(t)⋅sin(θₘ₃(t))
# ↪
# ↪ ─────────────────────────────────────────────────────────
# ↪
# ↪
# ↪

# %%
function3 = y_m2_func - Q3
solution3 = sp.solve(function3, sp.diff(sp.diff(y_m2, t), t))
solution3_simple = solution3[0].simplify()
sp.pprint(solution3_simple)
# Out:
#                                                                                ↪
#           ⎛       2    2                                                       ↪
# - 1.0⋅M⋅g⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t ↪
#                                                                                ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪     3/2                                                                      ↪
# ↪   2⎞             ⎛       2    2                                              ↪
# ↪ )) ⎠    + 1.0⋅Q₃⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t) ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪              3/2                 ___________________________________________ ↪
# ↪            2⎞               3   ╱        2    2                              ↪
# ↪ ) - yₘ₂(t)) ⎠    + 0.5⋅c₄⋅l₁ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____________________________                                       ________ ↪
# ↪                            2     2    d                     2      ╱         ↪
# ↪ .5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂ (t)⋅──(θₘ₂(t)) - 0.5⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ↪
# ↪                                       dt                                     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________________________________________________________             ↪
# ↪ 2    2                                                        2     2        ↪
# ↪  ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂ (t)⋅sin ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                        _____________________________________ ↪
# ↪          d                     2      ╱        2    2                        ↪
# ↪ (θₘ₃(t))⋅──(θₘ₃(t)) + 1.0⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂( ↪
# ↪          dt                                                                  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________________________________                                          ↪
# ↪                                  2                     d                     ↪
# ↪ t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅cos(θₘ₃(t))⋅──(θₘ₂(t)) - 1.0⋅c₄⋅l ↪
# ↪                                                        dt                    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪       ______________________________________________________________________ ↪
# ↪  2   ╱        2    2                                                         ↪
# ↪ ₁ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __                                    ______________________________________ ↪
# ↪ 2     2    d                     2   ╱        2    2                         ↪
# ↪   ⋅θₘ₂ (t)⋅──(yₘ₂(t)) - 2.0⋅c₄⋅l₁ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t ↪
# ↪            dt                                                                ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________                                           ↪
# ↪                                 2                d                         2 ↪
# ↪ ) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂(t)⋅──(θₘ₂(t)) + 0.25⋅c₄⋅l₁⋅l₃  ↪
# ↪                                                  dt                          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪     ________________________________________________________________________ ↪
# ↪    ╱        2    2                                                        2  ↪
# ↪ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))   ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                       ______________________ ↪
# ↪                         d                        2   ╱        2    2         ↪
# ↪ ⋅θₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(θₘ₃(t)) + 0.5⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) ↪
# ↪                         dt                                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________________________                           ↪
# ↪                                                 2     2         d            ↪
# ↪  + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅cos (θₘ₃(t))⋅──(θₘ₂(t)) - ↪
# ↪                                                                 dt           ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                   __________________________________________________________ ↪
# ↪              2   ╱        2    2                                             ↪
# ↪  0.5⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₁ ⋅θₘ₂ (t) + 0.5⋅l₁⋅l₃⋅θₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ₂( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _______________________________________________________                      ↪
# ↪                    2                              2                          ↪
# ↪ t)⋅yₘ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂(t)⋅cos(θₘ₃(t)) + yₘ₂ (t) ⋅θₘ₂(t)⋅sin(2.0⋅θₘ₃(t ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                 ____________________________________________ ↪
# ↪    d                           ╱        2    2                               ↪
# ↪ ))⋅──(θₘ₃(t)) + 2.0⋅c₄⋅l₁⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0. ↪
# ↪    dt                                                                        ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________                                                 ↪
# ↪                           2                            d                     ↪
# ↪ 5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂(t)⋅sin(θₘ₃(t))⋅──(θₘ₃(t)) - 2.0⋅c₄⋅l ↪
# ↪                                                        dt                    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪         ____________________________________________________________________ ↪
# ↪        ╱        2    2                                                       ↪
# ↪ ₁⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____                                                 _______________________ ↪
# ↪   2                     d                           ╱        2    2          ↪
# ↪ ))  ⋅θₘ₂(t)⋅cos(θₘ₃(t))⋅──(yₘ₂(t)) - 2.0⋅c₄⋅l₁⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t))  ↪
# ↪                         dt                                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _________________________________________________                            ↪
# ↪                                                2                     d       ↪
# ↪ + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅cos(θₘ₃(t))⋅──(θₘ₂( ↪
# ↪                                                                      dt      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                    _________________________________________________________ ↪
# ↪                   ╱        2    2                                            ↪
# ↪ t)) + 4.0⋅c₄⋅l₁⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _______________                                         ____________________ ↪
# ↪              2                d                        ╱        2    2       ↪
# ↪ t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂(t)⋅──(yₘ₂(t)) + 2.0⋅c₄⋅l₁⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t ↪
# ↪                               dt                                             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________                         ↪
# ↪                                                   2     2    d               ↪
# ↪ )) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂ (t)⋅──(θₘ₂(t)) - 0. ↪
# ↪                                                              dt              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪             ________________________________________________________________ ↪
# ↪        3   ╱        2    2                                                   ↪
# ↪ 5⋅c₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - y ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________                                                      ______________ ↪
# ↪       2                 2         d                      3   ╱        2    2 ↪
# ↪ ₘ₂(t))  ⋅sin(θₘ₃(t))⋅cos (θₘ₃(t))⋅──(θₘ₃(t)) + 0.25⋅c₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin  ↪
# ↪                                   dt                                         ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________________________________                   ↪
# ↪                                                         2                    ↪
# ↪ (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅sin(2.0⋅θₘ₃(t))⋅c ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                       ______________________________________ ↪
# ↪            d                     2   ╱        2    2                         ↪
# ↪ os(θₘ₃(t))⋅──(θₘ₃(t)) - 0.5⋅c₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t ↪
# ↪            dt                                                                ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________                                           ↪
# ↪                                 2                         d                  ↪
# ↪ ) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(θₘ₃(t)) - 1.0⋅c ↪
# ↪                                                           dt                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪          ___________________________________________________________________ ↪
# ↪     2   ╱        2    2                                                      ↪
# ↪ ₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____                                         ______________________________ ↪
# ↪    2     2         d                     2   ╱        2    2                 ↪
# ↪ t))  ⋅cos (θₘ₃(t))⋅──(yₘ₂(t)) + 1.0⋅c₄⋅l₃ ⋅╲╱  0.25⋅l₁ ⋅θₘ₂ (t) + 0.5⋅l₁⋅l₃⋅ ↪
# ↪                    dt                                                        ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                        ⎛       2    2                        ↪
# ↪                               (M + m₂)⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂( ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                2                             ↪
# ↪ θₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ₂(t)⋅yₘ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂(t)⋅cos(θₘ₃(t)) + y ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                    3/2                                       ↪
# ↪                                  2⎞                                          ↪
# ↪ t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠                                          ↪
#
# ↪ _______                                                  ___________________ ↪
# ↪   2                            d                        ╱        2    2      ↪
# ↪ ₘ₂ (t) ⋅yₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(θₘ₃(t)) - 2.0⋅c₄⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃( ↪
# ↪                                dt                                            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____________________________________________________                        ↪
# ↪                                                    2     2                d  ↪
# ↪ t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂ (t)⋅sin(θₘ₃(t))⋅── ↪
# ↪                                                                           dt ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                         ____________________________________________________ ↪
# ↪                        ╱        2    2                                       ↪
# ↪ (θₘ₃(t)) + 4.0⋅c₄⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________                                           _____________ ↪
# ↪                   2                     d                     ╱        2     ↪
# ↪ (θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅cos(θₘ₃(t))⋅──(yₘ₂(t)) - 4.0⋅c₄⋅╲╱  0.25⋅l₃ ⋅sin ↪
# ↪                                         dt                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________________________________________________________                  ↪
# ↪ 2                                                        2     2    d        ↪
# ↪  (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂ (t)⋅──(yₘ₂(t ↪
# ↪                                                                     dt       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪               ⎛       2    2                                                 ↪
# ↪ )) - 1.0⋅g⋅m₁⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪           3/2                                                                ↪
# ↪         2⎞               ⎛       2    2                                      ↪
# ↪  yₘ₂(t)) ⎠    - 1.0⋅g⋅m₂⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅co ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                      3/2                                                     ↪
# ↪                    2⎞               ⎛       2    2                           ↪
# ↪ s(θₘ₃(t)) - yₘ₂(t)) ⎠    - 1.0⋅g⋅m₃⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t)  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                 3/2                                          ↪
# ↪                               2⎞                ⎛       2    2               ↪
# ↪ + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠    - 1.0⋅k₁⋅l₁⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0. ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                             3/2                              ↪
# ↪                                           2⎞                         ⎛       ↪
# ↪ 5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅sin(θₘ₂(t)) - 1.0⋅k₁⋅⎝0.25⋅l ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                  3/2         ↪
# ↪  2    2                                                        2⎞            ↪
# ↪ ₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅yₘ₂(t)  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪          ⎛       2    2                                                      ↪
# ↪ - 1.0⋅k₂⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪      3/2                                                                     ↪
# ↪    2⎞                       ⎛       2    2                                   ↪
# ↪ t)) ⎠   ⋅yₘ₂(t) + 1.0⋅k₃⋅l₁⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                         3/2                                                  ↪
# ↪                       2⎞                         ⎛       2    2              ↪
# ↪ ⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅sin(θₘ₂(t)) - 1.0⋅k₃⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                              3/2                             ↪
# ↪                                            2⎞                          3     ↪
# ↪ .5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅yₘ₂(t) - 0.25⋅k₄⋅l₁⋅l₃ ⋅θₘ₂ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                     ________________________________________ ↪
# ↪        2                       2   ╱        2    2                           ↪
# ↪ (t)⋅sin (θₘ₃(t)) + 0.5⋅k₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t)  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________________________                                             ↪
# ↪                               2            2                                 ↪
# ↪ + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅sin (θₘ₃(t)) - 1.0⋅k₄⋅l₁⋅l₃⋅(0.5⋅l₁⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                              _______________ ↪
# ↪                                      2                      ╱        2    2  ↪
# ↪ θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅θₘ₂(t) + 2.0⋅k₄⋅l₁⋅╲╱  0.25⋅l₃ ⋅sin ( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _________________________________________________________                    ↪
# ↪                                                        2                     ↪
# ↪ θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅(0.5⋅l₁⋅θₘ₂(t) + 0 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                            2                    4    2                       ↪
# ↪ .5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅θₘ₂(t) - 0.25⋅k₄⋅l₃ ⋅sin (θₘ₃(t))⋅cos(θₘ₃(t)) + ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                _____________________________________________________________ ↪
# ↪           3   ╱        2    2                                                ↪
# ↪  0.5⋅k₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t))  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________                                                                  ↪
# ↪          2     2                                3           2                ↪
# ↪ - yₘ₂(t))  ⋅sin (θₘ₃(t))⋅cos(θₘ₃(t)) + 0.5⋅k₄⋅l₃ ⋅yₘ₂(t)⋅sin (θₘ₃(t)) - 1.0⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪           __________________________________________________________________ ↪
# ↪      2   ╱        2    2                                                     ↪
# ↪ k₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ______                                                                       ↪
# ↪     2            2                    2                                      ↪
# ↪ (t))  ⋅yₘ₂(t)⋅sin (θₘ₃(t)) - 1.0⋅k₄⋅l₃ ⋅(0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t))  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                       ______________________________________ ↪
# ↪          2                           ╱        2    2                         ↪
# ↪ - yₘ₂(t)) ⋅cos(θₘ₃(t)) + 2.0⋅k₄⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________                                           ↪
# ↪                                 2                                            ↪
# ↪ ) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅(0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪     2                                                                      2 ↪
# ↪ (t)) ⋅cos(θₘ₃(t)) + 2.0⋅k₄⋅l₃⋅(0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                     ________________________________________________________ ↪
# ↪                    ╱        2    2                                           ↪
# ↪ ⋅yₘ₂(t) - 4.0⋅k₄⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________
# ↪               2                                               2
# ↪ (t)) - yₘ₂(t))  ⋅(0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅yₘ₂(t)
# ↪
# ↪ ──────────────────────────────────────────────────────────────────────
# ↪
# ↪
# ↪

# %%
function4 = y_m2_func - Q4
solution4 = sp.solve(function4, sp.diff(sp.diff(y_m2, t), t))
solution4_simple = solution4[0].simplify()
sp.pprint(solution4_simple)
# Out:
#                                                                                ↪
#           ⎛       2    2                                                       ↪
# - 1.0⋅M⋅g⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t ↪
#                                                                                ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪     3/2                                                                      ↪
# ↪   2⎞             ⎛       2    2                                              ↪
# ↪ )) ⎠    + 1.0⋅Q₄⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t) ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪              3/2                 ___________________________________________ ↪
# ↪            2⎞               3   ╱        2    2                              ↪
# ↪ ) - yₘ₂(t)) ⎠    + 0.5⋅c₄⋅l₁ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____________________________                                       ________ ↪
# ↪                            2     2    d                     2      ╱         ↪
# ↪ .5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂ (t)⋅──(θₘ₂(t)) - 0.5⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ↪
# ↪                                       dt                                     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________________________________________________________             ↪
# ↪ 2    2                                                        2     2        ↪
# ↪  ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂ (t)⋅sin ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                        _____________________________________ ↪
# ↪          d                     2      ╱        2    2                        ↪
# ↪ (θₘ₃(t))⋅──(θₘ₃(t)) + 1.0⋅c₄⋅l₁ ⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂( ↪
# ↪          dt                                                                  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________________________________                                          ↪
# ↪                                  2                     d                     ↪
# ↪ t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅cos(θₘ₃(t))⋅──(θₘ₂(t)) - 1.0⋅c₄⋅l ↪
# ↪                                                        dt                    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪       ______________________________________________________________________ ↪
# ↪  2   ╱        2    2                                                         ↪
# ↪ ₁ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __                                    ______________________________________ ↪
# ↪ 2     2    d                     2   ╱        2    2                         ↪
# ↪   ⋅θₘ₂ (t)⋅──(yₘ₂(t)) - 2.0⋅c₄⋅l₁ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t ↪
# ↪            dt                                                                ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________                                           ↪
# ↪                                 2                d                         2 ↪
# ↪ ) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂(t)⋅──(θₘ₂(t)) + 0.25⋅c₄⋅l₁⋅l₃  ↪
# ↪                                                  dt                          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪     ________________________________________________________________________ ↪
# ↪    ╱        2    2                                                        2  ↪
# ↪ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))   ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                       ______________________ ↪
# ↪                         d                        2   ╱        2    2         ↪
# ↪ ⋅θₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(θₘ₃(t)) + 0.5⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) ↪
# ↪                         dt                                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________________________                           ↪
# ↪                                                 2     2         d            ↪
# ↪  + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅cos (θₘ₃(t))⋅──(θₘ₂(t)) - ↪
# ↪                                                                 dt           ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                   __________________________________________________________ ↪
# ↪              2   ╱        2    2                                             ↪
# ↪  0.5⋅c₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₁ ⋅θₘ₂ (t) + 0.5⋅l₁⋅l₃⋅θₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ₂( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _______________________________________________________                      ↪
# ↪                    2                              2                          ↪
# ↪ t)⋅yₘ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂(t)⋅cos(θₘ₃(t)) + yₘ₂ (t) ⋅θₘ₂(t)⋅sin(2.0⋅θₘ₃(t ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                 ____________________________________________ ↪
# ↪    d                           ╱        2    2                               ↪
# ↪ ))⋅──(θₘ₃(t)) + 2.0⋅c₄⋅l₁⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0. ↪
# ↪    dt                                                                        ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________                                                 ↪
# ↪                           2                            d                     ↪
# ↪ 5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂(t)⋅sin(θₘ₃(t))⋅──(θₘ₃(t)) - 2.0⋅c₄⋅l ↪
# ↪                                                        dt                    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪         ____________________________________________________________________ ↪
# ↪        ╱        2    2                                                       ↪
# ↪ ₁⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____                                                 _______________________ ↪
# ↪   2                     d                           ╱        2    2          ↪
# ↪ ))  ⋅θₘ₂(t)⋅cos(θₘ₃(t))⋅──(yₘ₂(t)) - 2.0⋅c₄⋅l₁⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t))  ↪
# ↪                         dt                                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _________________________________________________                            ↪
# ↪                                                2                     d       ↪
# ↪ + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅cos(θₘ₃(t))⋅──(θₘ₂( ↪
# ↪                                                                      dt      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                    _________________________________________________________ ↪
# ↪                   ╱        2    2                                            ↪
# ↪ t)) + 4.0⋅c₄⋅l₁⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _______________                                         ____________________ ↪
# ↪              2                d                        ╱        2    2       ↪
# ↪ t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅yₘ₂(t)⋅──(yₘ₂(t)) + 2.0⋅c₄⋅l₁⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t ↪
# ↪                               dt                                             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________                         ↪
# ↪                                                   2     2    d               ↪
# ↪ )) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂ (t)⋅──(θₘ₂(t)) - 0. ↪
# ↪                                                              dt              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪             ________________________________________________________________ ↪
# ↪        3   ╱        2    2                                                   ↪
# ↪ 5⋅c₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - y ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________                                                      ______________ ↪
# ↪       2                 2         d                      3   ╱        2    2 ↪
# ↪ ₘ₂(t))  ⋅sin(θₘ₃(t))⋅cos (θₘ₃(t))⋅──(θₘ₃(t)) + 0.25⋅c₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin  ↪
# ↪                                   dt                                         ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________________________________                   ↪
# ↪                                                         2                    ↪
# ↪ (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅sin(2.0⋅θₘ₃(t))⋅c ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                       ______________________________________ ↪
# ↪            d                     2   ╱        2    2                         ↪
# ↪ os(θₘ₃(t))⋅──(θₘ₃(t)) - 0.5⋅c₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t ↪
# ↪            dt                                                                ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________                                           ↪
# ↪                                 2                         d                  ↪
# ↪ ) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(θₘ₃(t)) - 1.0⋅c ↪
# ↪                                                           dt                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪          ___________________________________________________________________ ↪
# ↪     2   ╱        2    2                                                      ↪
# ↪ ₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____                                         ______________________________ ↪
# ↪    2     2         d                     2   ╱        2    2                 ↪
# ↪ t))  ⋅cos (θₘ₃(t))⋅──(yₘ₂(t)) + 1.0⋅c₄⋅l₃ ⋅╲╱  0.25⋅l₁ ⋅θₘ₂ (t) + 0.5⋅l₁⋅l₃⋅ ↪
# ↪                    dt                                                        ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                        ⎛       2    2                        ↪
# ↪                               (M + m₂)⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂( ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                2                             ↪
# ↪ θₘ₂(t)⋅cos(θₘ₃(t)) - l₁⋅θₘ₂(t)⋅yₘ₂(t) + 0.25⋅l₃  - l₃⋅yₘ₂(t)⋅cos(θₘ₃(t)) + y ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                    3/2                                       ↪
# ↪                                  2⎞                                          ↪
# ↪ t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠                                          ↪
#
# ↪ _______                                                  ___________________ ↪
# ↪   2                            d                        ╱        2    2      ↪
# ↪ ₘ₂ (t) ⋅yₘ₂(t)⋅sin(2.0⋅θₘ₃(t))⋅──(θₘ₃(t)) - 2.0⋅c₄⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃( ↪
# ↪                                dt                                            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _____________________________________________________                        ↪
# ↪                                                    2     2                d  ↪
# ↪ t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂ (t)⋅sin(θₘ₃(t))⋅── ↪
# ↪                                                                           dt ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                         ____________________________________________________ ↪
# ↪                        ╱        2    2                                       ↪
# ↪ (θₘ₃(t)) + 4.0⋅c₄⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________                                           _____________ ↪
# ↪                   2                     d                     ╱        2     ↪
# ↪ (θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂(t)⋅cos(θₘ₃(t))⋅──(yₘ₂(t)) - 4.0⋅c₄⋅╲╱  0.25⋅l₃ ⋅sin ↪
# ↪                                         dt                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________________________________________________________                  ↪
# ↪ 2                                                        2     2    d        ↪
# ↪  (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅yₘ₂ (t)⋅──(yₘ₂(t ↪
# ↪                                                                     dt       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪               ⎛       2    2                                                 ↪
# ↪ )) - 1.0⋅g⋅m₁⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪           3/2                                                                ↪
# ↪         2⎞               ⎛       2    2                                      ↪
# ↪  yₘ₂(t)) ⎠    - 1.0⋅g⋅m₂⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅co ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                      3/2                                                     ↪
# ↪                    2⎞               ⎛       2    2                           ↪
# ↪ s(θₘ₃(t)) - yₘ₂(t)) ⎠    - 1.0⋅g⋅m₃⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t)  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                 3/2                                          ↪
# ↪                               2⎞                ⎛       2    2               ↪
# ↪ + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠    - 1.0⋅k₁⋅l₁⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0. ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                             3/2                              ↪
# ↪                                           2⎞                         ⎛       ↪
# ↪ 5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅sin(θₘ₂(t)) - 1.0⋅k₁⋅⎝0.25⋅l ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                  3/2         ↪
# ↪  2    2                                                        2⎞            ↪
# ↪ ₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅yₘ₂(t)  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪          ⎛       2    2                                                      ↪
# ↪ - 1.0⋅k₂⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪      3/2                                                                     ↪
# ↪    2⎞                       ⎛       2    2                                   ↪
# ↪ t)) ⎠   ⋅yₘ₂(t) + 1.0⋅k₃⋅l₁⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                         3/2                                                  ↪
# ↪                       2⎞                         ⎛       2    2              ↪
# ↪ ⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅sin(θₘ₂(t)) - 1.0⋅k₃⋅⎝0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                              3/2                             ↪
# ↪                                            2⎞                          3     ↪
# ↪ .5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⎠   ⋅yₘ₂(t) - 0.25⋅k₄⋅l₁⋅l₃ ⋅θₘ₂ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                     ________________________________________ ↪
# ↪        2                       2   ╱        2    2                           ↪
# ↪ (t)⋅sin (θₘ₃(t)) + 0.5⋅k₄⋅l₁⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t)  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________________________                                             ↪
# ↪                               2            2                                 ↪
# ↪ + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅θₘ₂(t)⋅sin (θₘ₃(t)) - 1.0⋅k₄⋅l₁⋅l₃⋅(0.5⋅l₁⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                              _______________ ↪
# ↪                                      2                      ╱        2    2  ↪
# ↪ θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅θₘ₂(t) + 2.0⋅k₄⋅l₁⋅╲╱  0.25⋅l₃ ⋅sin ( ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ _________________________________________________________                    ↪
# ↪                                                        2                     ↪
# ↪ θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅(0.5⋅l₁⋅θₘ₂(t) + 0 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                            2                    4    2                       ↪
# ↪ .5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅θₘ₂(t) - 0.25⋅k₄⋅l₃ ⋅sin (θₘ₃(t))⋅cos(θₘ₃(t)) + ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                _____________________________________________________________ ↪
# ↪           3   ╱        2    2                                                ↪
# ↪  0.5⋅k₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t))  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ___________                                                                  ↪
# ↪          2     2                                3           2                ↪
# ↪ - yₘ₂(t))  ⋅sin (θₘ₃(t))⋅cos(θₘ₃(t)) + 0.5⋅k₄⋅l₃ ⋅yₘ₂(t)⋅sin (θₘ₃(t)) - 1.0⋅ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪           __________________________________________________________________ ↪
# ↪      2   ╱        2    2                                                     ↪
# ↪ k₄⋅l₃ ⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ______                                                                       ↪
# ↪     2            2                    2                                      ↪
# ↪ (t))  ⋅yₘ₂(t)⋅sin (θₘ₃(t)) - 1.0⋅k₄⋅l₃ ⋅(0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t))  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                       ______________________________________ ↪
# ↪          2                           ╱        2    2                         ↪
# ↪ - yₘ₂(t)) ⋅cos(θₘ₃(t)) + 2.0⋅k₄⋅l₃⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __________________________________                                           ↪
# ↪                                 2                                            ↪
# ↪ ) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ⋅(0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪     2                                                                      2 ↪
# ↪ (t)) ⋅cos(θₘ₃(t)) + 2.0⋅k₄⋅l₃⋅(0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t))  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                     ________________________________________________________ ↪
# ↪                    ╱        2    2                                           ↪
# ↪ ⋅yₘ₂(t) - 4.0⋅k₄⋅╲╱  0.25⋅l₃ ⋅sin (θₘ₃(t)) + (0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ________________
# ↪               2                                               2
# ↪ (t)) - yₘ₂(t))  ⋅(0.5⋅l₁⋅θₘ₂(t) + 0.5⋅l₃⋅cos(θₘ₃(t)) - yₘ₂(t)) ⋅yₘ₂(t)
# ↪
# ↪ ──────────────────────────────────────────────────────────────────────
# ↪
# ↪
# ↪

# %%
print(solution1_simple)
# Out:
# (1.0*Q1*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)**(3/2) - 0.25*c4*l1**4*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*Derivative(theta_m2(t), t) + 0.25*c4*l1**3*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*sin(theta_m3(t))*Derivative(theta_m3(t), t) - 0.5*c4*l1**3*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*cos(theta_m3(t))*Derivative(theta_m2(t), t) + 0.5*c4*l1**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*Derivative(y_m2(t), t) + 1.0*c4*l1**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*Derivative(theta_m2(t), t) - 0.125*c4*l1**2*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) - 0.25*c4*l1**2*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*cos(theta_m3(t))**2*Derivative(theta_m2(t), t) + 0.25*c4*l1**2*l3**2*sqrt(0.25*l1**2*theta_m2(t)**2 + 0.5*l1*l3*theta_m2(t)*cos(theta_m3(t)) - l1*theta_m2(t)*y_m2(t) + 0.25*l3**2 - l3*y_m2(t)*cos(theta_m3(t)) + y_m2(t)**2)*theta_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) - 1.0*c4*l1**2*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*sin(theta_m3(t))*Derivative(theta_m3(t), t) + 1.0*c4*l1**2*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*cos(theta_m3(t))*Derivative(y_m2(t), t) + 1.0*c4*l1**2*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)*cos(theta_m3(t))*Derivative(theta_m2(t), t) - 2.0*c4*l1**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*Derivative(y_m2(t), t) - 1.0*c4*l1**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*Derivative(theta_m2(t), t) + 0.25*c4*l1*l3**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*sin(theta_m3(t))*cos(theta_m3(t))**2*Derivative(theta_m3(t), t) - 0.125*c4*l1*l3**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*sin(2.0*theta_m3(t))*cos(theta_m3(t))*Derivative(theta_m3(t), t) + 0.25*c4*l1*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) + 0.5*c4*l1*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*cos(theta_m3(t))**2*Derivative(y_m2(t), t) - 0.5*c4*l1*l3**2*sqrt(0.25*l1**2*theta_m2(t)**2 + 0.5*l1*l3*theta_m2(t)*cos(theta_m3(t)) - l1*theta_m2(t)*y_m2(t) + 0.25*l3**2 - l3*y_m2(t)*cos(theta_m3(t)) + y_m2(t)**2)*y_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) + 1.0*c4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*sin(theta_m3(t))*Derivative(theta_m3(t), t) - 2.0*c4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)*cos(theta_m3(t))*Derivative(y_m2(t), t) + 2.0*c4*l1*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*Derivative(y_m2(t), t) - 1.0*g*l1*m1*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)**(3/2)*cos(theta_m2(t)) + 1.0*g*l1*m3*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)**(3/2)*cos ...

# %%
print(solution2_simple)
# Out:
# (1.0*Q2*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)**(3/2) + 0.25*c4*l1**3*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*sin(theta_m3(t))*Derivative(theta_m2(t), t) + 0.125*c4*l1**2*l3**2*sqrt(0.25*l1**2*theta_m2(t)**2 + 0.5*l1*l3*theta_m2(t)*cos(theta_m3(t)) - l1*theta_m2(t)*y_m2(t) + 0.25*l3**2 - l3*y_m2(t)*cos(theta_m3(t)) + y_m2(t)**2)*theta_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m2(t), t) - 0.5*c4*l1**2*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*sin(theta_m3(t))*Derivative(y_m2(t), t) - 1.0*c4*l1**2*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*sin(theta_m3(t))*Derivative(theta_m2(t), t) - 0.25*c4*l1*l3**2*sqrt(0.25*l1**2*theta_m2(t)**2 + 0.5*l1*l3*theta_m2(t)*cos(theta_m3(t)) - l1*theta_m2(t)*y_m2(t) + 0.25*l3**2 - l3*y_m2(t)*cos(theta_m3(t)) + y_m2(t)**2)*theta_m2(t)*sin(2.0*theta_m3(t))*Derivative(y_m2(t), t) - 0.25*c4*l1*l3**2*sqrt(0.25*l1**2*theta_m2(t)**2 + 0.5*l1*l3*theta_m2(t)*cos(theta_m3(t)) - l1*theta_m2(t)*y_m2(t) + 0.25*l3**2 - l3*y_m2(t)*cos(theta_m3(t)) + y_m2(t)**2)*y_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m2(t), t) + 2.0*c4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*sin(theta_m3(t))*Derivative(y_m2(t), t) + 1.0*c4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*sin(theta_m3(t))*Derivative(theta_m2(t), t) + 0.5*c4*l3**2*sqrt(0.25*l1**2*theta_m2(t)**2 + 0.5*l1*l3*theta_m2(t)*cos(theta_m3(t)) - l1*theta_m2(t)*y_m2(t) + 0.25*l3**2 - l3*y_m2(t)*cos(theta_m3(t)) + y_m2(t)**2)*y_m2(t)*sin(2.0*theta_m3(t))*Derivative(y_m2(t), t) - 2.0*c4*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*sin(theta_m3(t))*Derivative(y_m2(t), t) - 0.125*k4*l1*l3**4*theta_m2(t)*sin(theta_m3(t))**3 + 0.25*k4*l1*l3**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*sin(theta_m3(t))**3 - 0.5*k4*l1*l3**2*(0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2*theta_m2(t)*sin(theta_m3(t)) + 1.0*k4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*(0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2*theta_m2(t)*sin(theta_m3(t)) + 0.25*k4*l3**4*y_m2(t)*sin(theta_m3(t))**3 - 0.5*k4*l3**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)*sin(theta_m3(t))**3 + 1.0*k4*l3**2*(0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2*y_m2(t)*sin(theta_m3(t)) - 2.0*k4*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*(0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2*y_m2(t)*sin(theta_m3(t)))/(c4*l3**2*(0.5*l1*theta_m2(t) - y_m2(t))**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*sin(theta_m3(t))**2)

# %%
print(solution3_simple)
# Out:
# (-1.0*M*g*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)**(3/2) + 1.0*Q3*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)**(3/2) + 0.5*c4*l1**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*Derivative(theta_m2(t), t) - 0.5*c4*l1**2*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*sin(theta_m3(t))*Derivative(theta_m3(t), t) + 1.0*c4*l1**2*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*cos(theta_m3(t))*Derivative(theta_m2(t), t) - 1.0*c4*l1**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*Derivative(y_m2(t), t) - 2.0*c4*l1**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*Derivative(theta_m2(t), t) + 0.25*c4*l1*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) + 0.5*c4*l1*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*cos(theta_m3(t))**2*Derivative(theta_m2(t), t) - 0.5*c4*l1*l3**2*sqrt(0.25*l1**2*theta_m2(t)**2 + 0.5*l1*l3*theta_m2(t)*cos(theta_m3(t)) - l1*theta_m2(t)*y_m2(t) + 0.25*l3**2 - l3*y_m2(t)*cos(theta_m3(t)) + y_m2(t)**2)*theta_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) + 2.0*c4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*sin(theta_m3(t))*Derivative(theta_m3(t), t) - 2.0*c4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*cos(theta_m3(t))*Derivative(y_m2(t), t) - 2.0*c4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)*cos(theta_m3(t))*Derivative(theta_m2(t), t) + 4.0*c4*l1*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*Derivative(y_m2(t), t) + 2.0*c4*l1*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*Derivative(theta_m2(t), t) - 0.5*c4*l3**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*sin(theta_m3(t))*cos(theta_m3(t))**2*Derivative(theta_m3(t), t) + 0.25*c4*l3**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*sin(2.0*theta_m3(t))*cos(theta_m3(t))*Derivative(theta_m3(t), t) - 0.5*c4*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) - 1.0*c4*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*cos(theta_m3(t))**2*Derivative(y_m2(t), t) + 1.0*c4*l3**2*sqrt(0.25*l1**2*theta_m2(t)**2 + 0.5*l1*l3*theta_m2(t)*cos(theta_m3(t)) - l1*theta_m2(t)*y_m2(t) + 0.25*l3**2 - l3*y_m2(t)*cos(theta_m3(t)) + y_m2(t)**2)*y_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) - 2.0*c4*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*sin(theta_m3(t))*Derivative(theta_m3(t), t) + 4.0*c4*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)*cos(theta_m3(t))*Derivative(y_m2(t), t) - 4.0*c4*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*Derivative(y_m2(t), t) - 1.0*g*m1*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)**(3/2) - 1.0*g*m2*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(thet ...

# %%
print(solution4_simple)
# Out:
# (-1.0*M*g*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)**(3/2) + 1.0*Q4*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)**(3/2) + 0.5*c4*l1**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*Derivative(theta_m2(t), t) - 0.5*c4*l1**2*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*sin(theta_m3(t))*Derivative(theta_m3(t), t) + 1.0*c4*l1**2*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*cos(theta_m3(t))*Derivative(theta_m2(t), t) - 1.0*c4*l1**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)**2*Derivative(y_m2(t), t) - 2.0*c4*l1**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*Derivative(theta_m2(t), t) + 0.25*c4*l1*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) + 0.5*c4*l1*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*cos(theta_m3(t))**2*Derivative(theta_m2(t), t) - 0.5*c4*l1*l3**2*sqrt(0.25*l1**2*theta_m2(t)**2 + 0.5*l1*l3*theta_m2(t)*cos(theta_m3(t)) - l1*theta_m2(t)*y_m2(t) + 0.25*l3**2 - l3*y_m2(t)*cos(theta_m3(t)) + y_m2(t)**2)*theta_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) + 2.0*c4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*sin(theta_m3(t))*Derivative(theta_m3(t), t) - 2.0*c4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*cos(theta_m3(t))*Derivative(y_m2(t), t) - 2.0*c4*l1*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)*cos(theta_m3(t))*Derivative(theta_m2(t), t) + 4.0*c4*l1*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*theta_m2(t)*y_m2(t)*Derivative(y_m2(t), t) + 2.0*c4*l1*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*Derivative(theta_m2(t), t) - 0.5*c4*l3**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*sin(theta_m3(t))*cos(theta_m3(t))**2*Derivative(theta_m3(t), t) + 0.25*c4*l3**3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*sin(2.0*theta_m3(t))*cos(theta_m3(t))*Derivative(theta_m3(t), t) - 0.5*c4*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) - 1.0*c4*l3**2*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*cos(theta_m3(t))**2*Derivative(y_m2(t), t) + 1.0*c4*l3**2*sqrt(0.25*l1**2*theta_m2(t)**2 + 0.5*l1*l3*theta_m2(t)*cos(theta_m3(t)) - l1*theta_m2(t)*y_m2(t) + 0.25*l3**2 - l3*y_m2(t)*cos(theta_m3(t)) + y_m2(t)**2)*y_m2(t)*sin(2.0*theta_m3(t))*Derivative(theta_m3(t), t) - 2.0*c4*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*sin(theta_m3(t))*Derivative(theta_m3(t), t) + 4.0*c4*l3*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)*cos(theta_m3(t))*Derivative(y_m2(t), t) - 4.0*c4*sqrt(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)*y_m2(t)**2*Derivative(y_m2(t), t) - 1.0*g*m1*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(theta_m3(t)) - y_m2(t))**2)**(3/2) - 1.0*g*m2*(0.25*l3**2*sin(theta_m3(t))**2 + (0.5*l1*theta_m2(t) + 0.5*l3*cos(thet ...

# %%
theta_m2_dot = sp.symbols('theta_m2_dot')
theta_m3_dot = sp.symbols('theta_m3_dot')
y_m2_dot = sp.symbols('y_m2_dot')
y_M_dot = sp.symbols('y_M_dot')
theta_m2_ddot = sp.symbols('theta_m2_ddot')
theta_m3_ddot = sp.symbols('theta_m3_ddot')
y_m2_ddot = sp.symbols('y_m2_ddot')
y_M_ddot = sp.symbols('y_M_ddot')
# Out:
# √t

# %%
replacement = {
    sp.Derivative(sp.Derivative(theta_m2, t), t): theta_m2_ddot,
    sp.Derivative(sp.Derivative(theta_m3, t), t): theta_m3_ddot,
    sp.Derivative(sp.Derivative(y_m2, t), t): y_m2_ddot,
    sp.Derivative(sp.Derivative(y_M, t), t): y_M_ddot,
    sp.diff(theta_m2, t): theta_m2_dot,
    sp.diff(theta_m3, t): theta_m3_dot,
    sp.diff(y_m2, t): y_m2_dot,
    sp.diff(y_M, t): y_M_dot
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 2
#       1 replacement = {
# ----> 2     sp.Derivative(sp.Derivative(theta_m2, t), t): theta_m2_ddot,
#       3     sp.Derivative(sp.Derivative(theta_m3, t), t): theta_m3_ddot,
#       4     sp.Derivative(sp.Derivative(y_m2, t), t): y_m2_ddot,
#       5     sp.Derivative(sp.Derivative(y_M, t), t): y_M_ddot,
#       6     sp.diff(theta_m2, t): theta_m2_dot,
#       7     sp.diff(theta_m3, t): theta_m3_dot,
#       8     sp.diff(y_m2, t): y_m2_dot,
#       9     sp.diff(y_M, t): y_M_dot
#      10 }
#
# NameError: name 'theta_m2_ddot' is not defined

# %%
solution1_simple = solution1_simple.subs(replacement)
solution2_simple = solution2_simple.subs(replacement)
solution3_simple = solution3_simple.subs(replacement)
solution4_simple = solution4_simple.subs(replacement)
